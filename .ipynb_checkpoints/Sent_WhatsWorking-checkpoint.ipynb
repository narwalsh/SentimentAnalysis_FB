# %%
"""
by Patrick Walsh
February 8, 2016

Conduct sentiment analysis on up to the first 50 comments for all whats working posts and a 
randomly selected subset of other posts."""

from sentiment_analysis import avg_sentiment
import pandas as pd
import numpy as np

file_name = "FB_Main_AllPost_Insights_Nov2015Jan2016_WhatsWorking.csv"
all_data = pd.read_csv(file_name)

# %%
whats_working_data = all_data[all_data['whatsworking']=='WhatsWorking']

# %%
other_data = all_data[all_data['whatsworking']!='WhatsWorking']

# %%
other_sample = other_data.sample(n = 500)

# %%
# Out:
#                  caption  comments        DateTime  \
# 1260             huff.to       574    11/7/15 1:00
# 188              huff.to       601  11/25/15 17:39
# 3260             huff.to       447   1/25/16 21:35
# 241                  NaN       505  11/24/15 20:15
# 2030             huff.to       351  12/22/15 13:00
# 3137             pubx.co        22    1/28/16 5:28
# 2669             huff.to       187    12/8/15 6:01
# 1438             huff.to        21   11/4/15 14:40
# 2222                 NaN       269  12/17/15 22:29
# 2833                 NaN      3542   12/4/15 20:15
# 1980             huff.to       152  12/23/15 11:00
# 3381             huff.to       262   1/22/16 14:37
# 3053             huff.to       188    1/30/16 0:05
# 4068             huff.to       220     1/7/16 3:40
# 2476                 NaN        89   12/12/15 3:21
# 1581  huffingtonpost.com       186   11/2/15 14:00
# 3665                 NaN       705   1/15/16 17:45
# ...
